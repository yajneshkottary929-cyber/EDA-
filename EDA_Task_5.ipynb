# %%
import pandas as pd

# %%
df=pd.read_csv("healthcare_dataset.csv")

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
df.dtypes
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number             int64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
df["Date of Admission"].value_counts()
# Out:
# Date of Admission
# 2024-03-16    50
# 2022-07-24    49
# 2020-10-22    49
# 2021-12-28    48
# 2021-01-03    48
#               ..
# 2023-04-12    14
# 2022-05-28    14
# 2022-05-23    13
# 2019-07-22    13
# 2022-02-05    12
# Name: count, Length: 1827, dtype: int64

# %%
df["Discharge Date"].value_counts()
# Out:
# Discharge Date
# 2020-03-15    53
# 2021-12-13    51
# 2020-12-02    51
# 2023-04-29    51
# 2020-08-11    50
#               ..
# 2019-05-11     2
# 2024-06-04     2
# 2024-06-05     2
# 2019-05-09     1
# 2024-06-06     1
# Name: count, Length: 1856, dtype: int64

# %%
df["Medical Condition"].value_counts()
# Out:
# Medical Condition
# Arthritis       9308
# Diabetes        9304
# Hypertension    9245
# Obesity         9231
# Cancer          9227
# Asthma          9185
# Name: count, dtype: int64

# %%
df["Admission Type"].value_counts()
# Out:
# Admission Type
# Elective     18655
# Urgent       18576
# Emergency    18269
# Name: count, dtype: int64

# %%
def categories_urgancy(Admission):
    if Admission=="Emergency":
        return"Imediat care"
    elif Admission=="Urgent":
        return "High priority"
    else:
        return"planned care"
df["priority_level"]=df["Admission Type"].apply(categories_urgancy)   
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df["Date of Admission"]=pd.to_datetime(df["Date of Admission"])

# %%
df["Discharge Date"]=pd.to_datetime(df["Discharge Date"])

# %%
df["Medical Condition"].value_counts()
# Out:
# Medical Condition
# Arthritis       9308
# Diabetes        9304
# Hypertension    9245
# Obesity         9231
# Cancer          9227
# Asthma          9185
# Name: count, dtype: int64

# %%
df["Hospital stay days"]=(df["Date of Admission"]-df["Discharge Date"]).dt.days

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df[["Age","Billing Amount","Hospital stay days"]].describe()
# Out:
#                 Age  Billing Amount  Hospital stay days
# count  55500.000000    55500.000000        55500.000000
# mean      51.539459    25539.316097          -15.509009
# std       19.602454    14211.454431            8.659600
# min       13.000000    -2008.492140          -30.000000
# 25%       35.000000    13241.224652          -23.000000
# 50%       52.000000    25538.069376          -15.000000
# 75%       68.000000    37820.508436           -8.000000
# max       89.000000    52764.276736           -1.000000

# %%
df.groupby("Medical Condition")["Age"].mean()
# Out:
# Medical Condition
# Arthritis       51.565320
# Asthma          51.575830
# Cancer          51.558795
# Diabetes        51.554170
# Hypertension    51.741915
# Obesity         51.240277
# Name: Age, dtype: float64

# %%
df.groupby("Medical Condition")["Hospital stay days"].mean()
# Out:
# Medical Condition
# Arthritis      -15.517404
# Asthma         -15.696570
# Cancer         -15.495827
# Diabetes       -15.422936
# Hypertension   -15.458626
# Obesity        -15.464305
# Name: Hospital stay days, dtype: float64

# %%
df.groupby("Medical Condition")["Billing Amount"].mean()
# Out:
# Medical Condition
# Arthritis       25497.327056
# Asthma          25635.249359
# Cancer          25161.792707
# Diabetes        25638.405577
# Hypertension    25497.095761
# Obesity         25805.971259
# Name: Billing Amount, dtype: float64

# %%
df.groupby("Admission Type")["Billing Amount"].mean()
# Out:
# Admission Type
# Elective     25602.226311
# Emergency    25497.397157
# Urgent       25517.364497
# Name: Billing Amount, dtype: float64

# %%
df.groupby("Hospital stay days")["Billing Amount"].mean()
# Out:
# Hospital stay days
# -30    25385.377704
# -29    24803.920175
# -28    25795.107005
# -27    25489.474170
# -26    25558.598635
# -25    25277.975015
# -24    25823.469559
# -23    25909.965880
# -22    25394.876295
# -21    25435.698929
# -20    25881.437922
# -19    25125.441052
# -18    24795.852102
# -17    25386.882852
# -16    25735.807571
# -15    25701.125864
# -14    26286.287593
# -13    24943.186404
# -12    25499.902778
# -11    25118.402379
# -10    25434.418732
# -9     25558.196644
# -8     26123.387559
# -7     25729.109970
# -6     25939.124560
# -5     25472.856088
# -4     26005.481458
# -3     25963.830821
# -2     25288.455308
# -1     25310.914450
# Name: Billing Amount, dtype: float64

# %%
pd.crosstab(
    df["Medical Condition"],
    df["Gender"])
# Out:
# Gender             Female  Male
# Medical Condition
# Arthritis            4686  4622
# Asthma               4553  4632
# Cancer               4602  4625
# Diabetes             4651  4653
# Hypertension         4612  4633
# Obesity              4622  4609
